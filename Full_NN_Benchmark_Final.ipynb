# %%
# %%capture cap
import numpy as np
import warnings; warnings.simplefilter('ignore')
import torch
import torch.nn as nn
from torch.autograd import Variable
import os
import logging
import onnx
import tvm
import tvm.micro as micro
from tvm.contrib import graph_executor, utils
from tvm import relay
import subprocess
from tvm.micro.contrib import zephyr
import sys
# %matplotlib inline

# %%
temp_file_directory = '/home/vagrant/test_models/un1'

# %%
TARGET = tvm.target.target.micro("stm32f746xx")
BOARD = "nucleo_f746zg" # or "stm32f746g_disco#"

repo_root = subprocess.check_output(["git", "rev-parse", "--show-toplevel"], encoding='utf-8').strip()
project_dir = os.path.join(repo_root, "apps", "microtvm", "zephyr", "demo_runtime")
compiler = zephyr.ZephyrCompiler(project_dir=project_dir,board=BOARD,zephyr_toolchain_variant="zephyr",)

opts = tvm.micro.default_options(f"{project_dir}/crt")
workspace = tvm.micro.Workspace()
flasher = compiler.flasher()

def onnx_relay(model,L1,L2,L3,node,i_size):
    lstm = model(L1,L2,L3)
    print(lstm)
    pytorch_total_params = sum(p.numel() for p in lstm.parameters())
    print("Total Number of Parameters: ", pytorch_total_params)
    os.chdir(str(temp_file_directory))
    torch.save(lstm, "./lstm.pt")
    model = torch.load("./lstm.pt")
    model.eval()
    inputs = Variable(torch.randn(i_size))
    torch.onnx.export(model,inputs,"lstm.onnx", verbose=False)
    model_path = os.path.join(os.getcwd(),"lstm.onnx")
    model = onnx.load(model_path)
    input_name = str(node)
    shape_dict = {input_name: tuple(i_size)}
    mod, params = relay.frontend.from_onnx(model, shape_dict)
    return mod , params


def build_flash(mod,TARGET,params,input_mcu,node):
    workspace = tvm.micro.Workspace()
    with tvm.transform.PassContext(opt_level=3, config={"tir.disable_vectorize": True}):
        graph, c_mod, c_params = relay.build(mod, target=TARGET, params=params)
        micro_binary = tvm.micro.build_static_runtime(workspace,compiler,c_mod,opts,extra_libs=[tvm.micro.get_standalone_crt_lib("memory")],)
        print(os.path.join(micro_binary.base_dir, micro_binary.binary_file))
        print("****************************************************************************")
        !~/zephyr-sdk/arm-zephyr-eabi/bin/arm-zephyr-eabi-size {os.path.join(micro_binary.base_dir, micro_binary.binary_file)}
        print("****************************************************************************")

    with tvm.micro.Session(binary=micro_binary, flasher=flasher) as session:
        graph_mod = tvm.micro.create_local_debug_executor(graph, session.get_system_lib(), session.device)
        graph_mod.set_input(**c_params)
        graph_mod.set_input(str(node), tvm.nd.array(input_mcu))
        graph_mod.run()
        tvm_output = graph_mod.get_output(0).asnumpy()
        print(tvm_output.shape)
        tvm_output = torch.unsqueeze(torch.tensor(tvm_output),0)
        print(tvm_output.shape)
    return tvm_output

# %%
i_ifc = []
o_ifc = []
i_l= []
o_l= []
i_ffc = []
o_ffc = []
sequence_length = []

stack = []
splits = [0,0,0,0,0,0]
flag = 0
index = 0
mode = 0 #1
user = 0

# %%
print("****************************************************************************")
print("Enable User Input? 1 for Yes 0 for No")
user = int(input())
print("****************************************************************************")
# Out:
# ****************************************************************************
# Enable User Input? 1 for Yes 0 for No
# 1
# ****************************************************************************

# %%
if (user == 1):
    print("****************************************************************************")
    initial_fc_layers = int(input("Enter the number of fc layers before lstm blocks"))
    print("****************************************************************************")
    lstm_layers = int(input("MAX number of lstm blocks"))
    print("****************************************************************************")
    final_fc_layers = int(input("Enter the number of fc layers after the lstm blocks"))
    print("****************************************************************************")


    total_layers = initial_fc_layers + lstm_layers + final_fc_layers
    if (initial_fc_layers != 0):  
        for each in range(0,initial_fc_layers):
            if (each == 0):
                print("****************************************************************************")
                print("Enter Input size of the Neural Network")
                t1 = int(input("Size: "))
                i_ifc.append(t1)
            print("****************************************************************************")
            print("Enter Output size of initial_fc_layer: ", (each+1))
            t2 = int(input("Size: "))
            o_ifc.append(t2)
            if (each != (initial_fc_layers-1)):
                i_ifc.append(t2)
    else:
        i_ffc= [0]* total_layers
        o_ffc= [0]* total_layers


    if (lstm_layers != 0):    
        for each in range(0,lstm_layers):
            print("****************************************************************************")
            if (each == 0):
                print("Keep same time sequence processing length of all lstm blocks? 0 for NO and 1 for Yes")
                d1 = int(input())
            if (d1 != 1):
                print("Enter sequence length of lstm layer: ", each+1)
                t3 = int(input("length: "))
                sequence_length.append(t3)
            else:
                if (each == 0):
                    print("Enter common sequence length for all the blocks:")
                    t3 = int(input("length: "))
                    sequence_length = [t3]*lstm_layers
            if (each == 0):
                print("****************************************************************************")
                print("Keep same stacking of all lstm blocks? 0 for NO and 1 for Yes")
                d2 = int(input())
            if (d2 != 1):
                print("****************************************************************************")
                print("Enter stacking layers in lstm layer: ", each+1)
                t4 = int(input("stacked by: "))
                stack.append(t4)
            else:
                if (each == 0):
                    print("Enter common stacking for all the blocks:")
                    t4 = int(input("length: "))
                    stack = [t4]*lstm_layers    
                
            if (each == 0):
                if (initial_fc_layers == 0):
                    print("####################################################################")
                    print("Enter Input size of lstm_layer: ", (each+1))
                    t1 = int(input("Size: "))
                    i_l.append(t1)
                else:
                    i_l.append(o_ifc[initial_fc_layers-1])

            print("****************************************************************************")
            print("Enter Output size of lstm_layer: ", (each+1))
            t2 = int(input("Size: "))
            o_l.append(t2)



            if (each>0):
                if (sequence_length[each] == sequence_length[each-1]):
                    i_l.append(o_l[each-1])
                else:
                    a = int((sequence_length[each-1])*(o_l[each-1]))
                    b = int(sequence_length[each])
                    i_l.append(int(a/b))                   
    else:
        stack = [1]* total_layers
        sequence_length = [1]* total_layers
        i_l= [0]* total_layers
        o_l= [0]* total_layers

   
    if (final_fc_layers != 0):  
        for each in range(0,final_fc_layers):
            if (each == 0):
                if ((initial_fc_layers == 0) and (lstm_layers == 0)):    
                    print("****************************************************************************")
                    print("Enter Input size of final_fc_layer: ", (each+1))
                    t1 = int(input("Size: "))
                    i_ffc.append(t1)
                else:
                    if (lstm_layers != 0): 
                        i_ffc.append(o_l[lstm_layers-1])
                    else:
                        i_ffc.append(o_ifc[initial_fc_layers-1])

            print("****************************************************************************")
            print("Enter Output size of final_fc_layer: ", (each+1))
            t2 = int(input("Size: "))
            o_ffc.append(t2)
            if (each != (initial_fc_layers-1)):
                i_ffc.append(t2)        

    else:
        i_ffc= [0]* total_layers
        o_ffc= [0]* total_layers

else:
    print("****************************************************************************")
    print("Using Default values written in the script!!")
    initial_fc_layers = 3
    lstm_layers = 3
    final_fc_layers = 3


    i_ifc = [6,8]
    o_ifc = [8,16]
    i_l= [10,8]
    o_l= [8,4]
    i_ffc = [4,3]
    o_ffc = [3,2,1]
    sequence_length = [8,8]




    stack = [1,1]
    splits = [0,0]
    flag = 0
    index = 0
    mode = 0 #1
    user = 0

    total_layers = initial_fc_layers + lstm_layers + final_fc_layers
    print("****************************************************************************")
# Out:
# ****************************************************************************
# Enter the number of fc layers before lstm blocks4
# ****************************************************************************
# MAX number of lstm blocks4
# ****************************************************************************
# Enter the number of fc layers after the lstm blocks4
# ****************************************************************************
# ****************************************************************************
# Enter Input size of the Neural Network
# Size: 6
# ****************************************************************************
# Enter Output size of initial_fc_layer:  1
# Size: 8
# ****************************************************************************
# Enter Output size of initial_fc_layer:  2
# Size: 10
# ****************************************************************************
# Enter Output size of initial_fc_layer:  3
# Size: 12
# ****************************************************************************
# Enter Output size of initial_fc_layer:  4
# Size: 16
# ****************************************************************************
# Keep same time sequence processing length of all lstm blocks? 0 for NO and 1 for Yes
# 1
# Enter common sequence length for all the blocks:
# length: 8
# ****************************************************************************
# Keep same stacking of all lstm blocks? 0 for NO and 1 for Yes
# 1
# Enter common stacking for all the blocks:
# length: 1
# ****************************************************************************
# Enter Output size of lstm_layer:  1
# Size: 16
# ****************************************************************************
# ****************************************************************************
# Enter Output size of lstm_layer:  2
# Size: 12
# ****************************************************************************
# ****************************************************************************
# Enter Output size of lstm_layer:  3
# Size: 10
# ****************************************************************************
# ****************************************************************************
# Enter Output size of lstm_layer:  4
# Size: 8
# ****************************************************************************
# Enter Output size of final_fc_layer:  1
# Size: 6
# ****************************************************************************
# Enter Output size of final_fc_layer:  2
# Size: 4
# ****************************************************************************
# Enter Output size of final_fc_layer:  3
# Size: 2
# ****************************************************************************
# Enter Output size of final_fc_layer:  4
# Size: 1

# %%
print("Final Network:")
if (lstm_layers != 0):
    print("Initial Fully Connected layers:")
    for each in range(0,initial_fc_layers):
        print("("+str(i_ifc[each])+")=>("+str(o_ifc[each])+")")

if (lstm_layers != 0):
    print("lstms:")
    for each in range(0,lstm_layers):
        print("("+str(i_l[each])+")=>("+str(o_l[each])+")")

if (final_fc_layers!= 0): 
    print("Final Fully Connected layers:")
    for each in range(0,final_fc_layers):
        print("("+str(i_ffc[each])+")=>("+str(o_ffc[each])+")")
# Out:
# Final Network:
# Initial Fully Connected layers:
# (6)=>(8)
# (8)=>(10)
# (10)=>(12)
# (12)=>(16)
# lstms:
# (16)=>(16)
# (16)=>(12)
# (12)=>(10)
# (10)=>(8)
# Final Fully Connected layers:
# (8)=>(6)
# (6)=>(4)
# (4)=>(2)
# (2)=>(1)

# %%
class LSTM(nn.Module):
    def __init__(self,a,b,c):
        super(LSTM, self).__init__()
        
        self.p1 = a
        self.p2 = b
        self.p3 = c

        #Inital fc layers
        if (self.p1 != 0):
            linears1 =[]
            for i in range(0,initial_fc_layers):
                linears1.append(nn.Linear(i_ifc[i], o_ifc[i]))
            self.fc = nn.ModuleList(linears1)

        #lstm layers
        if (self.p2 != 0): 
            l_modules = []
            for i in range(0,lstm_layers):
                l_modules.append(nn.LSTM(input_size=i_l[i], hidden_size=o_l[i],
                                       num_layers=stack[i], batch_first=True))
            self.lstm = nn.ModuleList(l_modules)
        
        #Final fc layers 
        if (self.p3 != 0):
            linears2 =[]
            in1 = o_l[lstm_layers-1]
            for i in range(0,final_fc_layers):                
                linears2.append(nn.Linear(in1,o_ffc[i]))
                in1 = o_ffc[i]
            self.fc2 = nn.ModuleList(linears2)


    def forward(self, x):

        out =  [0] * (total_layers+2)

        if (self.p1 != 0):
            x = x.view(-1, i_ifc[0])
            out[0] = x
            for i in range(0,initial_fc_layers):
                print("here ifc", i)
                out[i+1]= self.fc[i](out[i])
            out2 = out[initial_fc_layers]
            out[0] = out2
        else:
            out2 =x
            
        
        if (self.p2 != 0):
            out2 = out2.view(1,sequence_length[0],i_l[0])
            for i in range(0,lstm_layers):
                h= Variable(torch.zeros(stack[i], out2.size(0), o_l[i]))
                c= Variable(torch.zeros(stack[i], out2.size(0), o_l[i]))
                print("here l", i)
                ula, (h_out1, _) = self.lstm[i](out2, (h, c))
                if (i == (lstm_layers-1)):
                    h_out = h_out1.view(-1, o_l[i]) 
                else:
                    out2 = ula.view(1,sequence_length[i+1],i_l[i+1])

            out[0] = h_out  
        
        else:
            if (self.p3 != 0) and (self.p1 == 0):
                x = x.view(-1, i_ffc[0])
                out[0] = x
                
                
                
        if (self.p3 != 0):
            out[0] = out[0].view(-1, i_ffc[0])
            for i in range(0,final_fc_layers):
                print("here ffc", i)
                out[i+1]= self.fc2[i](out[i])
            out[0]= out[final_fc_layers]

        return out[0]

# %%
input_size = (1,sequence_length[0],i_ifc[0])
tensor1 = torch.Tensor(np.random.uniform(low=0.1, high=0.2, size=input_size))
node = 0
mod , params = onnx_relay(LSTM,initial_fc_layers,lstm_layers,final_fc_layers,node,input_size)
tvm_output = build_flash(mod,TARGET,params,tensor1,node)
# Out:
# LSTM(
#   (fc): ModuleList(
#     (0): Linear(in_features=6, out_features=8, bias=True)
#     (1): Linear(in_features=8, out_features=10, bias=True)
#     (2): Linear(in_features=10, out_features=12, bias=True)
#     (3): Linear(in_features=12, out_features=16, bias=True)
#   )
#   (lstm): ModuleList(
#     (0): LSTM(16, 16, batch_first=True)
#     (1): LSTM(16, 12, batch_first=True)
#     (2): LSTM(12, 10, batch_first=True)
#     (3): LSTM(10, 8, batch_first=True)
#   )
#   (fc2): ModuleList(
#     (0): Linear(in_features=8, out_features=6, bias=True)
#     (1): Linear(in_features=6, out_features=4, bias=True)
#     (2): Linear(in_features=4, out_features=2, bias=True)
#     (3): Linear(in_features=2, out_features=1, bias=True)
#   )
# )
# Total Number of Parameters:  5797
# here l 0
# here l 1
# here l 2
# here l 3
# Cannot find config for target=llvm -keys=cpu -link-params=0, workload=('dense_pack.x86', ('TENSOR', (1, 16), 'float32'), ('TENSOR', (64, 16), 'float32'), None, 'float32'). A fallback configuration is used, which may bring great performance regression.
# Cannot find config for target=llvm -keys=cpu -link-params=0, workload=('dense_pack.x86', ('TENSOR', (1, 12), 'float32'), ('TENSOR', (48, 12), 'float32'), None, 'float32'). A fallback configuration is used, which may bring great performance regression.
# Cannot find config for target=llvm -keys=cpu -link-params=0, workload=('dense_pack.x86', ('TENSOR', (1, 10), 'float32'), ('TENSOR', (40, 10), 'float32'), None, 'float32'). A fallback configuration is used, which may bring great performance regression.
# Cannot find config for target=llvm -keys=cpu -link-params=0, workload=('dense_pack.x86', ('TENSOR', (1, 8), 'float32'), ('TENSOR', (32, 8), 'float32'), None, 'float32'). A fallback configuration is used, which may bring great performance regression.
# Cannot find config for target=c -keys=cpu -link-params=0 -march=armv7e-m -mcpu=cortex-m7 -model=stm32f746xx -runtime=c -system-lib=1, workload=('dense_pack.x86', ('TENSOR', (8, 6), 'float32'), ('TENSOR', (8, 6), 'float32'), None, 'float32'). A fallback configuration is used, which may bring great performance regression.
# Cannot find config for target=c -keys=cpu -link-params=0 -march=armv7e-m -mcpu=cortex-m7 -model=stm32f746xx -runtime=c -system-lib=1, workload=('dense_pack.x86', ('TENSOR', (8, 8), 'float32'), ('TENSOR', (10, 8), 'float32'), None, 'float32'). A fallback configuration is used, which may bring great performance regression.
# Cannot find config for target=c -keys=cpu -link-params=0 -march=armv7e-m -mcpu=cortex-m7 -model=stm32f746xx -runtime=c -system-lib=1, workload=('dense_pack.x86', ('TENSOR', (8, 10), 'float32'), ('TENSOR', (12, 10), 'float32'), None, 'float32'). A fallback configuration is used, which may bring great performance regression.
# Cannot find config for target=c -keys=cpu -link-params=0 -march=armv7e-m -mcpu=cortex-m7 -model=stm32f746xx -runtime=c -system-lib=1, workload=('dense_pack.x86', ('TENSOR', (8, 12), 'float32'), ('TENSOR', (16, 12), 'float32'), None, 'float32'). A fallback configuration is used, which may bring great performance regression.
# Cannot find config for target=c -keys=cpu -link-params=0 -march=armv7e-m -mcpu=cortex-m7 -model=stm32f746xx -runtime=c -system-lib=1, workload=('dense_pack.x86', ('TENSOR', (1, 16), 'float32'), ('TENSOR', (64, 16), 'float32'), None, 'float32'). A fallback configuration is used, which may bring great performance regression.
# Cannot find config for target=c -keys=cpu -link-params=0 -march=armv7e-m -mcpu=cortex-m7 -model=stm32f746xx -runtime=c -system-lib=1, workload=('dense_pack.x86', ('TENSOR', (1, 16), 'float32'), ('TENSOR', (48, 16), 'float32'), None, 'float32'). A fallback configuration is used, which may bring great performance regression.
# Cannot find config for target=c -keys=cpu -link-params=0 -march=armv7e-m -mcpu=cortex-m7 -model=stm32f746xx -runtime=c -system-lib=1, workload=('dense_pack.x86', ('TENSOR', (1, 12), 'float32'), ('TENSOR', (48, 12), 'float32'), None, 'float32'). A fallback configuration is used, which may bring great performance regression.
# Cannot find config for target=c -keys=cpu -link-params=0 -march=armv7e-m -mcpu=cortex-m7 -model=stm32f746xx -runtime=c -system-lib=1, workload=('dense_pack.x86', ('TENSOR', (1, 12), 'float32'), ('TENSOR', (40, 12), 'float32'), None, 'float32'). A fallback configuration is used, which may bring great performance regression.
# Cannot find config for target=c -keys=cpu -link-params=0 -march=armv7e-m -mcpu=cortex-m7 -model=stm32f746xx -runtime=c -system-lib=1, workload=('dense_pack.x86', ('TENSOR', (1, 10), 'float32'), ('TENSOR', (40, 10), 'float32'), None, 'float32'). A fallback configuration is used, which may bring great performance regression.
# Cannot find config for target=c -keys=cpu -link-params=0 -march=armv7e-m -mcpu=cortex-m7 -model=stm32f746xx -runtime=c -system-lib=1, workload=('dense_pack.x86', ('TENSOR', (1, 10), 'float32'), ('TENSOR', (32, 10), 'float32'), None, 'float32'). A fallback configuration is used, which may bring great performance regression.
# Cannot find config for target=c -keys=cpu -link-params=0 -march=armv7e-m -mcpu=cortex-m7 -model=stm32f746xx -runtime=c -system-lib=1, workload=('dense_pack.x86', ('TENSOR', (1, 8), 'float32'), ('TENSOR', (32, 8), 'float32'), None, 'float32'). A fallback configuration is used, which may bring great performance regression.
# Cannot find config for target=c -keys=cpu -link-params=0 -march=armv7e-m -mcpu=cortex-m7 -model=stm32f746xx -runtime=c -system-lib=1, workload=('dense_pack.x86', ('TENSOR', (1, 8), 'float32'), ('TENSOR', (6, 8), 'float32'), None, 'float32'). A fallback configuration is used, which may bring great performance regression.
# Cannot find config for target=c -keys=cpu -link-params=0 -march=armv7e-m -mcpu=cortex-m7 -model=stm32f746xx -runtime=c -system-lib=1, workload=('dense_pack.x86', ('TENSOR', (1, 6), 'float32'), ('TENSOR', (4, 6), 'float32'), None, 'float32'). A fallback configuration is used, which may bring great performance regression.
# Cannot find config for target=c -keys=cpu -link-params=0 -march=armv7e-m -mcpu=cortex-m7 -model=stm32f746xx -runtime=c -system-lib=1, workload=('dense_pack.x86', ('TENSOR', (1, 4), 'float32'), ('TENSOR', (2, 4), 'float32'), None, 'float32'). A fallback configuration is used, which may bring great performance regression.
# Cannot find config for target=c -keys=cpu -link-params=0 -march=armv7e-m -mcpu=cortex-m7 -model=stm32f746xx -runtime=c -system-lib=1, workload=('dense_pack.x86', ('TENSOR', (1, 2), 'float32'), ('TENSOR', (1, 2), 'float32'), None, 'float32'). A fallback configuration is used, which may bring great performance regression.
# Cannot find config for target=c -keys=cpu -link-params=0 -march=armv7e-m -mcpu=cortex-m7 -model=stm32f746xx -runtime=c -system-lib=1, workload=('dense_pack.x86', ('TENSOR', (1, 2), 'float32'), ('TENSOR', (1, 2, 1), 'float32'), None, 'float32'). A fallback configuration is used, which may bring great performance regression.
# Cannot find config for target=c -keys=cpu -link-params=0 -march=armv7e-m -mcpu=cortex-m7 -model=stm32f746xx -runtime=c -system-lib=1, workload=('dense_pack.x86', ('TENSOR', (1, 4), 'float32'), ('TENSOR', (1, 4, 2), 'float32'), None, 'float32'). A fallback configuration is used, which may bring great performance regression.
# Cannot find config for target=c -keys=cpu -link-params=0 -march=armv7e-m -mcpu=cortex-m7 -model=stm32f746xx -runtime=c -system-lib=1, workload=('dense_pack.x86', ('TENSOR', (1, 6), 'float32'), ('TENSOR', (1, 6, 4), 'float32'), None, 'float32'). A fallback configuration is used, which may bring great performance regression.
# Cannot find config for target=c -keys=cpu -link-params=0 -march=armv7e-m -mcpu=cortex-m7 -model=stm32f746xx -runtime=c -system-lib=1, workload=('dense_pack.x86', ('TENSOR', (1, 8), 'float32'), ('TENSOR', (1, 8, 6), 'float32'), None, 'float32'). A fallback configuration is used, which may bring great performance regression.
# Cannot find config for target=c -keys=cpu -link-params=0 -march=armv7e-m -mcpu=cortex-m7 -model=stm32f746xx -runtime=c -system-lib=1, workload=('dense_pack.x86', ('TENSOR', (1, 10), 'float32'), ('TENSOR', (2, 10, 16), 'float32'), None, 'float32'). A fallback configuration is used, which may bring great performance regression.
# Cannot find config for target=c -keys=cpu -link-params=0 -march=armv7e-m -mcpu=cortex-m7 -model=stm32f746xx -runtime=c -system-lib=1, workload=('dense_pack.x86', ('TENSOR', (1, 12), 'float32'), ('TENSOR', (4, 12, 10), 'float32'), None, 'float32'). A fallback configuration is used, which may bring great performance regression.
# Cannot find config for target=c -keys=cpu -link-params=0 -march=armv7e-m -mcpu=cortex-m7 -model=stm32f746xx -runtime=c -system-lib=1, workload=('dense_pack.x86', ('TENSOR', (1, 16), 'float32'), ('TENSOR', (3, 16, 16), 'float32'), None, 'float32'). A fallback configuration is used, which may bring great performance regression.
# Cannot find config for target=c -keys=cpu -link-params=0 -march=armv7e-m -mcpu=cortex-m7 -model=stm32f746xx -runtime=c -system-lib=1, workload=('dense_pack.x86', ('TENSOR', (1, 16), 'float32'), ('TENSOR', (4, 16, 16), 'float32'), None, 'float32'). A fallback configuration is used, which may bring great performance regression.
# Cannot find config for target=c -keys=cpu -link-params=0 -march=armv7e-m -mcpu=cortex-m7 -model=stm32f746xx -runtime=c -system-lib=1, workload=('dense_pack.x86', ('TENSOR', (8, 12), 'float32'), ('TENSOR', (1, 12, 16), 'float32'), None, 'float32'). A fallback configuration is used, which may bring great performance regression.
# Cannot find config for target=c -keys=cpu -link-params=0 -march=armv7e-m -mcpu=cortex-m7 -model=stm32f746xx -runtime=c -system-lib=1, workload=('dense_pack.x86', ('TENSOR', (8, 10), 'float32'), ('TENSOR', (1, 10, 12), 'float32'), None, 'float32'). A fallback configuration is used, which may bring great performance regression.
# Cannot find config for target=c -keys=cpu -link-params=0 -march=armv7e-m -mcpu=cortex-m7 -model=stm32f746xx -runtime=c -system-lib=1, workload=('dense_pack.x86', ('TENSOR', (8, 8), 'float32'), ('TENSOR', (1, 8, 10), 'float32'), None, 'float32'). A fallback configuration is used, which may bring great performance regression.
# Cannot find config for target=c -keys=cpu -link-params=0 -march=armv7e-m -mcpu=cortex-m7 -model=stm32f746xx -runtime=c -system-lib=1, workload=('dense_pack.x86', ('TENSOR', (8, 6), 'float32'), ('TENSOR', (1, 6, 8), 'float32'), None, 'float32'). A fallback configuration is used, which may bring great performance regression.
# Cannot find config for target=c -keys=cpu -link-params=0 -march=armv7e-m -mcpu=cortex-m7 -model=stm32f746xx -runtime=c -system-lib=1, workload=('dense_pack.x86', ('TENSOR', (1, 12), 'float32'), ('TENSOR', (3, 12, 16), 'float32'), None, 'float32'). A fallback configuration is used, which may bring great performance regression.
# Cannot find config for target=c -keys=cpu -link-params=0 -march=armv7e-m -mcpu=cortex-m7 -model=stm32f746xx -runtime=c -system-lib=1, workload=('dense_pack.x86', ('TENSOR', (1, 10), 'float32'), ('TENSOR', (4, 10, 10), 'float32'), None, 'float32'). A fallback configuration is used, which may bring great performance regression.
# Cannot find config for target=c -keys=cpu -link-params=0 -march=armv7e-m -mcpu=cortex-m7 -model=stm32f746xx -runtime=c -system-lib=1, workload=('dense_pack.x86', ('TENSOR', (1, 8), 'float32'), ('TENSOR', (2, 8, 16), 'float32'), None, 'float32'). A fallback configuration is used, which may bring great performance regression.
# /tmp/tmpfwdpz4m3/build/runtime/zephyr/zephyr.elf
# ****************************************************************************
#    text	   data	    bss	    dec	    hex	filename
#   51018	   1429	 235616	 288063	  4653f	/tmp/tmpfwdpz4m3/build/runtime/zephyr/zephyr.elf
# ****************************************************************************
# Node Name                                                                                                 Ops                                                                                                       Time(us)   Time(%)  Shape       Inputs  Outputs
# ---------                                                                                                 ---                                                                                                       --------   -------  -----       ------  -------
# fused_nn_contrib_dense_pack_add_4                                                                         fused_nn_contrib_dense_pack_add_4                                                                         240.437    1.741    (8, 16)     3       1
# fused_nn_contrib_dense_pack_add_add_36                                                                    fused_nn_contrib_dense_pack_add_add_3                                                                     232.775    1.686    (1, 64)     4       1
# fused_nn_contrib_dense_pack_add_add_37                                                                    fused_nn_contrib_dense_pack_add_add_3                                                                     232.381    1.683    (1, 64)     4       1
# fused_nn_contrib_dense_pack_add_add_35                                                                    fused_nn_contrib_dense_pack_add_add_3                                                                     231.207    1.674    (1, 64)     4       1
# fused_nn_contrib_dense_pack_add_add_32                                                                    fused_nn_contrib_dense_pack_add_add_3                                                                     231.086    1.674    (1, 64)     4       1
# fused_nn_contrib_dense_pack_add_add_34                                                                    fused_nn_contrib_dense_pack_add_add_3                                                                     230.961    1.673    (1, 64)     4       1
# fused_nn_contrib_dense_pack_add_add_3                                                                     fused_nn_contrib_dense_pack_add_add_3                                                                     230.956    1.673    (1, 64)     4       1
# fused_nn_contrib_dense_pack_add_add_33                                                                    fused_nn_contrib_dense_pack_add_add_3                                                                     230.846    1.672    (1, 64)     4       1
# fused_nn_contrib_dense_pack_add_add_31                                                                    fused_nn_contrib_dense_pack_add_add_3                                                                     230.84     1.672    (1, 64)     4       1
# fused_nn_contrib_dense_pack5                                                                              fused_nn_contrib_dense_pack                                                                               226.764    1.642    (1, 64)     2       1
# fused_nn_contrib_dense_pack6                                                                              fused_nn_contrib_dense_pack                                                                               225.911    1.636    (1, 64)     2       1
# fused_nn_contrib_dense_pack4                                                                              fused_nn_contrib_dense_pack                                                                               225.23     1.631    (1, 64)     2       1
# fused_nn_contrib_dense_pack1                                                                              fused_nn_contrib_dense_pack                                                                               225.212    1.631    (1, 64)     2       1
# fused_nn_contrib_dense_pack                                                                               fused_nn_contrib_dense_pack                                                                               225.117    1.63     (1, 64)     2       1
# fused_nn_contrib_dense_pack2                                                                              fused_nn_contrib_dense_pack                                                                               225.099    1.63     (1, 64)     2       1
# fused_nn_contrib_dense_pack3                                                                              fused_nn_contrib_dense_pack                                                                               225.042    1.63     (1, 64)     2       1
# fused_nn_contrib_dense_pack_add_add_25                                                                    fused_nn_contrib_dense_pack_add_add_2                                                                     175.45     1.271    (1, 48)     4       1
# fused_nn_contrib_dense_pack_add_add_24                                                                    fused_nn_contrib_dense_pack_add_add_2                                                                     175.26     1.269    (1, 48)     4       1
# fused_nn_contrib_dense_pack_add_add_21                                                                    fused_nn_contrib_dense_pack_add_add_2                                                                     175.16     1.268    (1, 48)     4       1
# fused_nn_contrib_dense_pack_add_add_2                                                                     fused_nn_contrib_dense_pack_add_add_2                                                                     175.142    1.268    (1, 48)     4       1
# fused_nn_contrib_dense_pack_add_add_26                                                                    fused_nn_contrib_dense_pack_add_add_2                                                                     175.079    1.268    (1, 48)     4       1
# fused_nn_contrib_dense_pack_add_add_22                                                                    fused_nn_contrib_dense_pack_add_add_2                                                                     175.053    1.268    (1, 48)     4       1
# fused_nn_contrib_dense_pack_add_add_23                                                                    fused_nn_contrib_dense_pack_add_add_2                                                                     175.026    1.268    (1, 48)     4       1
# fused_nn_contrib_dense_pack_add_add_27                                                                    fused_nn_contrib_dense_pack_add_add_2                                                                     175.003    1.267    (1, 48)     4       1
# fused_nn_contrib_dense_pack_add_5                                                                         fused_nn_contrib_dense_pack_add_5                                                                         164.104    1.188    (8, 12)     3       1
# fused_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_ex_16164666046576613888__2  fused_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_ex_16164666046576613888__2  159.303    1.154    (1, 1, 16)  9       8
# fused_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_ex_16164666046576613888__2  fused_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_ex_16164666046576613888__2  159.303    1.154    (1, 1, 16)  9       8
# fused_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_ex_16164666046576613888__2  fused_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_ex_16164666046576613888__2  159.303    1.154    (1, 1, 16)  9       8
# fused_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_ex_16164666046576613888__2  fused_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_ex_16164666046576613888__2  159.303    1.154    (1, 1, 16)  9       8
# fused_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_ex_16164666046576613888__2  fused_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_ex_16164666046576613888__2  159.303    1.154    (1, 1, 16)  9       8
# fused_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_ex_16164666046576613888__2  fused_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_ex_16164666046576613888__2  159.303    1.154    (1, 1, 16)  9       8
# fused_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_ex_16164666046576613888__2  fused_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_ex_16164666046576613888__2  159.303    1.154    (1, 1, 16)  9       8
# fused_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_ex_16164666046576613888__2  fused_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_ex_16164666046576613888__2  159.303    1.154    (1, 1, 16)  9       8
# fused_nn_contrib_dense_pack_add_add_1                                                                     fused_nn_contrib_dense_pack_add_add_1                                                                     158.235    1.146    (1, 40)     4       1
# fused_nn_contrib_dense_pack_add_add_17                                                                    fused_nn_contrib_dense_pack_add_add_1                                                                     157.821    1.143    (1, 40)     4       1
# fused_nn_contrib_dense_pack_add_add_15                                                                    fused_nn_contrib_dense_pack_add_add_1                                                                     157.749    1.142    (1, 40)     4       1
# fused_nn_contrib_dense_pack_add_add_14                                                                    fused_nn_contrib_dense_pack_add_add_1                                                                     157.729    1.142    (1, 40)     4       1
# fused_nn_contrib_dense_pack_add_add_16                                                                    fused_nn_contrib_dense_pack_add_add_1                                                                     157.71     1.142    (1, 40)     4       1
# fused_nn_contrib_dense_pack_add_add_12                                                                    fused_nn_contrib_dense_pack_add_add_1                                                                     157.683    1.142    (1, 40)     4       1
# fused_nn_contrib_dense_pack_add_add_11                                                                    fused_nn_contrib_dense_pack_add_add_1                                                                     157.626    1.142    (1, 40)     4       1
# fused_nn_contrib_dense_pack_add_add_13                                                                    fused_nn_contrib_dense_pack_add_add_1                                                                     157.592    1.141    (1, 40)     4       1
# fused_nn_contrib_dense_pack_14                                                                            fused_nn_contrib_dense_pack_1                                                                             145.147    1.051    (1, 48)     2       1
# fused_nn_contrib_dense_pack_12                                                                            fused_nn_contrib_dense_pack_1                                                                             144.98     1.05     (1, 48)     2       1
# fused_nn_contrib_dense_pack_11                                                                            fused_nn_contrib_dense_pack_1                                                                             144.951    1.05     (1, 48)     2       1
# fused_nn_contrib_dense_pack_16                                                                            fused_nn_contrib_dense_pack_1                                                                             144.936    1.05     (1, 48)     2       1
# fused_nn_contrib_dense_pack_13                                                                            fused_nn_contrib_dense_pack_1                                                                             144.932    1.05     (1, 48)     2       1
# fused_nn_contrib_dense_pack_1                                                                             fused_nn_contrib_dense_pack_1                                                                             144.906    1.049    (1, 48)     2       1
# fused_nn_contrib_dense_pack_15                                                                            fused_nn_contrib_dense_pack_1                                                                             144.744    1.048    (1, 48)     2       1
# fused_nn_contrib_dense_pack_2                                                                             fused_nn_contrib_dense_pack_2                                                                             142.694    1.033    (1, 40)     2       1
# fused_nn_contrib_dense_pack_25                                                                            fused_nn_contrib_dense_pack_2                                                                             142.664    1.033    (1, 40)     2       1
# fused_nn_contrib_dense_pack_26                                                                            fused_nn_contrib_dense_pack_2                                                                             142.557    1.032    (1, 40)     2       1
# fused_nn_contrib_dense_pack_23                                                                            fused_nn_contrib_dense_pack_2                                                                             142.525    1.032    (1, 40)     2       1
# fused_nn_contrib_dense_pack_24                                                                            fused_nn_contrib_dense_pack_2                                                                             142.476    1.032    (1, 40)     2       1
# fused_nn_contrib_dense_pack_22                                                                            fused_nn_contrib_dense_pack_2                                                                             142.369    1.031    (1, 40)     2       1
# fused_nn_contrib_dense_pack_21                                                                            fused_nn_contrib_dense_pack_2                                                                             141.976    1.028    (1, 40)     2       1
# fused_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_ex_16164666046576613888__1  fused_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_ex_16164666046576613888__1  121.454    0.88     (1, 1, 12)  9       8
# fused_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_ex_16164666046576613888__1  fused_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_ex_16164666046576613888__1  121.454    0.88     (1, 1, 12)  9       8
# fused_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_ex_16164666046576613888__1  fused_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_ex_16164666046576613888__1  121.454    0.88     (1, 1, 12)  9       8
# fused_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_ex_16164666046576613888__1  fused_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_ex_16164666046576613888__1  121.454    0.88     (1, 1, 12)  9       8
# fused_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_ex_16164666046576613888__1  fused_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_ex_16164666046576613888__1  121.454    0.88     (1, 1, 12)  9       8
# fused_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_ex_16164666046576613888__1  fused_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_ex_16164666046576613888__1  121.454    0.88     (1, 1, 12)  9       8
# fused_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_ex_16164666046576613888__1  fused_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_ex_16164666046576613888__1  121.454    0.88     (1, 1, 12)  9       8
# fused_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_ex_16164666046576613888__1  fused_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_ex_16164666046576613888__1  121.454    0.88     (1, 1, 12)  9       8
# fused_nn_contrib_dense_pack_add_6                                                                         fused_nn_contrib_dense_pack_add_6                                                                         120.863    0.875    (8, 10)     3       1
# fused_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_ex_16164666046576613888_    fused_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_ex_16164666046576613888_    101.518    0.735    (1, 1, 10)  9       8
# fused_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_ex_16164666046576613888_    fused_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_ex_16164666046576613888_    101.518    0.735    (1, 1, 10)  9       8
# fused_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_ex_16164666046576613888_    fused_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_ex_16164666046576613888_    101.518    0.735    (1, 1, 10)  9       8
# fused_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_ex_16164666046576613888_    fused_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_ex_16164666046576613888_    101.518    0.735    (1, 1, 10)  9       8
# fused_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_ex_16164666046576613888_    fused_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_ex_16164666046576613888_    101.518    0.735    (1, 1, 10)  9       8
# fused_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_ex_16164666046576613888_    fused_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_ex_16164666046576613888_    101.518    0.735    (1, 1, 10)  9       8
# fused_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_ex_16164666046576613888_    fused_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_ex_16164666046576613888_    101.518    0.735    (1, 1, 10)  9       8
# fused_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_ex_16164666046576613888_    fused_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_expand_dims_ex_16164666046576613888_    101.518    0.735    (1, 1, 10)  9       8
# fused_nn_contrib_dense_pack_add_add3                                                                      fused_nn_contrib_dense_pack_add_add                                                                       91.193     0.66     (1, 32)     4       1
# fused_nn_contrib_dense_pack_add_add5                                                                      fused_nn_contrib_dense_pack_add_add                                                                       91.187     0.66     (1, 32)     4       1
# fused_nn_contrib_dense_pack_add_add6                                                                      fused_nn_contrib_dense_pack_add_add                                                                       91.177     0.66     (1, 32)     4       1
# fused_nn_contrib_dense_pack_add_add2                                                                      fused_nn_contrib_dense_pack_add_add                                                                       91.16      0.66     (1, 32)     4       1
# fused_nn_contrib_dense_pack_add_add1                                                                      fused_nn_contrib_dense_pack_add_add                                                                       91.151     0.66     (1, 32)     4       1
# fused_nn_contrib_dense_pack_add_add                                                                       fused_nn_contrib_dense_pack_add_add                                                                       91.151     0.66     (1, 32)     4       1
# fused_nn_contrib_dense_pack_add_add4                                                                      fused_nn_contrib_dense_pack_add_add                                                                       91.133     0.66     (1, 32)     4       1
# fused_nn_contrib_dense_pack_add_add7                                                                      fused_nn_contrib_dense_pack_add_add                                                                       91.108     0.66     (1, 32)     4       1
# fused_sigmoid_multiply_sigmoid_tanh_multiply_add                                                          fused_sigmoid_multiply_sigmoid_tanh_multiply_add                                                          89.674     0.649    (1, 16)     5       1
# fused_sigmoid_multiply_sigmoid_tanh_multiply_add1                                                         fused_sigmoid_multiply_sigmoid_tanh_multiply_add                                                          89.308     0.647    (1, 16)     5       1
# fused_sigmoid_multiply_sigmoid_tanh_multiply_add3                                                         fused_sigmoid_multiply_sigmoid_tanh_multiply_add                                                          89.182     0.646    (1, 16)     5       1
# fused_sigmoid_multiply_sigmoid_tanh_multiply_add6                                                         fused_sigmoid_multiply_sigmoid_tanh_multiply_add                                                          89.117     0.645    (1, 16)     5       1
# fused_sigmoid_multiply_sigmoid_tanh_multiply_add4                                                         fused_sigmoid_multiply_sigmoid_tanh_multiply_add                                                          89.098     0.645    (1, 16)     5       1
# fused_sigmoid_multiply_sigmoid_tanh_multiply_add5                                                         fused_sigmoid_multiply_sigmoid_tanh_multiply_add                                                          89.062     0.645    (1, 16)     5       1
# fused_sigmoid_multiply_sigmoid_tanh_multiply_add2                                                         fused_sigmoid_multiply_sigmoid_tanh_multiply_add                                                          88.921     0.644    (1, 16)     5       1
# fused_nn_contrib_dense_pack_add_7                                                                         fused_nn_contrib_dense_pack_add_7                                                                         85.444     0.619    (8, 8)      3       1
# fused_nn_contrib_dense_pack_3                                                                             fused_nn_contrib_dense_pack_3                                                                             79.501     0.576    (1, 32)     2       1
# fused_nn_contrib_dense_pack_33                                                                            fused_nn_contrib_dense_pack_3                                                                             79.487     0.576    (1, 32)     2       1
# fused_nn_contrib_dense_pack_32                                                                            fused_nn_contrib_dense_pack_3                                                                             79.483     0.576    (1, 32)     2       1
# fused_nn_contrib_dense_pack_34                                                                            fused_nn_contrib_dense_pack_3                                                                             79.475     0.576    (1, 32)     2       1
# fused_nn_contrib_dense_pack_31                                                                            fused_nn_contrib_dense_pack_3                                                                             79.417     0.575    (1, 32)     2       1
# fused_nn_contrib_dense_pack_35                                                                            fused_nn_contrib_dense_pack_3                                                                             79.362     0.575    (1, 32)     2       1
# fused_nn_contrib_dense_pack_36                                                                            fused_nn_contrib_dense_pack_3                                                                             79.292     0.574    (1, 32)     2       1
# fused_split_sigmoid_sigmoid_multiply_sigmoid_tanh_multiply_add_tanh_multiply_exp_6397278466198362424_     fused_split_sigmoid_sigmoid_multiply_sigmoid_tanh_multiply_add_tanh_multiply_exp_6397278466198362424_     77.813     0.564    (1, 8)      2       1
# fused_sigmoid_multiply_sigmoid_tanh_multiply_add_16                                                       fused_sigmoid_multiply_sigmoid_tanh_multiply_add_1                                                        68.514     0.496    (1, 12)     5       1
# fused_sigmoid_multiply_sigmoid_tanh_multiply_add_15                                                       fused_sigmoid_multiply_sigmoid_tanh_multiply_add_1                                                        68.501     0.496    (1, 12)     5       1
# fused_sigmoid_multiply_sigmoid_tanh_multiply_add_1                                                        fused_sigmoid_multiply_sigmoid_tanh_multiply_add_1                                                        68.221     0.494    (1, 12)     5       1
# fused_sigmoid_multiply_sigmoid_tanh_multiply_add_14                                                       fused_sigmoid_multiply_sigmoid_tanh_multiply_add_1                                                        68.178     0.494    (1, 12)     5       1
# fused_sigmoid_multiply_sigmoid_tanh_multiply_add_13                                                       fused_sigmoid_multiply_sigmoid_tanh_multiply_add_1                                                        68.167     0.494    (1, 12)     5       1
# fused_sigmoid_multiply_sigmoid_tanh_multiply_add_11                                                       fused_sigmoid_multiply_sigmoid_tanh_multiply_add_1                                                        67.764     0.491    (1, 12)     5       1
# fused_sigmoid_multiply_sigmoid_tanh_multiply_add_12                                                       fused_sigmoid_multiply_sigmoid_tanh_multiply_add_1                                                        67.715     0.49     (1, 12)     5       1
# fused_sigmoid_tanh_multiply_26                                                                            fused_sigmoid_tanh_multiply_2                                                                             61.06      0.442    (1, 16)     5       1
# fused_sigmoid_tanh_multiply_24                                                                            fused_sigmoid_tanh_multiply_2                                                                             61.048     0.442    (1, 16)     5       1
# fused_sigmoid_tanh_multiply_25                                                                            fused_sigmoid_tanh_multiply_2                                                                             61.048     0.442    (1, 16)     5       1
# fused_sigmoid_tanh_multiply_23                                                                            fused_sigmoid_tanh_multiply_2                                                                             60.057     0.435    (1, 16)     5       1
# fused_sigmoid_tanh_multiply_22                                                                            fused_sigmoid_tanh_multiply_2                                                                             60.051     0.435    (1, 16)     5       1
# fused_sigmoid_tanh_multiply_21                                                                            fused_sigmoid_tanh_multiply_2                                                                             59.599     0.432    (1, 16)     5       1
# fused_sigmoid_tanh_multiply_2                                                                             fused_sigmoid_tanh_multiply_2                                                                             58.216     0.422    (1, 16)     5       1
# fused_sigmoid_multiply_sigmoid_tanh_multiply_add_2                                                        fused_sigmoid_multiply_sigmoid_tanh_multiply_add_2                                                        57.192     0.414    (1, 10)     5       1
# fused_sigmoid_multiply_sigmoid_tanh_multiply_add_23                                                       fused_sigmoid_multiply_sigmoid_tanh_multiply_add_2                                                        56.756     0.411    (1, 10)     5       1
# fused_sigmoid_multiply_sigmoid_tanh_multiply_add_21                                                       fused_sigmoid_multiply_sigmoid_tanh_multiply_add_2                                                        56.478     0.409    (1, 10)     5       1
# fused_sigmoid_multiply_sigmoid_tanh_multiply_add_22                                                       fused_sigmoid_multiply_sigmoid_tanh_multiply_add_2                                                        56.465     0.409    (1, 10)     5       1
# fused_sigmoid_multiply_sigmoid_tanh_multiply_add_26                                                       fused_sigmoid_multiply_sigmoid_tanh_multiply_add_2                                                        56.022     0.406    (1, 10)     5       1
# fused_sigmoid_multiply_sigmoid_tanh_multiply_add_25                                                       fused_sigmoid_multiply_sigmoid_tanh_multiply_add_2                                                        56.017     0.406    (1, 10)     5       1
# fused_sigmoid_multiply_sigmoid_tanh_multiply_add_24                                                       fused_sigmoid_multiply_sigmoid_tanh_multiply_add_2                                                        56.009     0.406    (1, 10)     5       1
# fused_sigmoid_multiply_sigmoid_tanh_multiply_add_3                                                        fused_sigmoid_multiply_sigmoid_tanh_multiply_add_3                                                        46.872     0.339    (1, 8)      5       1
# fused_sigmoid_multiply_sigmoid_tanh_multiply_add_35                                                       fused_sigmoid_multiply_sigmoid_tanh_multiply_add_3                                                        46.595     0.337    (1, 8)      5       1
# fused_sigmoid_multiply_sigmoid_tanh_multiply_add_33                                                       fused_sigmoid_multiply_sigmoid_tanh_multiply_add_3                                                        46.587     0.337    (1, 8)      5       1
# fused_sigmoid_multiply_sigmoid_tanh_multiply_add_34                                                       fused_sigmoid_multiply_sigmoid_tanh_multiply_add_3                                                        46.58      0.337    (1, 8)      5       1
# fused_sigmoid_multiply_sigmoid_tanh_multiply_add_36                                                       fused_sigmoid_multiply_sigmoid_tanh_multiply_add_3                                                        46.569     0.337    (1, 8)      5       1
# fused_sigmoid_multiply_sigmoid_tanh_multiply_add_32                                                       fused_sigmoid_multiply_sigmoid_tanh_multiply_add_3                                                        46.567     0.337    (1, 8)      5       1
# fused_sigmoid_multiply_sigmoid_tanh_multiply_add_31                                                       fused_sigmoid_multiply_sigmoid_tanh_multiply_add_3                                                        46.458     0.336    (1, 8)      5       1
# fused_sigmoid_tanh_multiply_14                                                                            fused_sigmoid_tanh_multiply_1                                                                             46.088     0.334    (1, 12)     5       1
# fused_sigmoid_tanh_multiply_16                                                                            fused_sigmoid_tanh_multiply_1                                                                             46.081     0.334    (1, 12)     5       1
# fused_sigmoid_tanh_multiply_13                                                                            fused_sigmoid_tanh_multiply_1                                                                             46.075     0.334    (1, 12)     5       1
# fused_sigmoid_tanh_multiply_12                                                                            fused_sigmoid_tanh_multiply_1                                                                             46.06      0.334    (1, 12)     5       1
# fused_sigmoid_tanh_multiply_15                                                                            fused_sigmoid_tanh_multiply_1                                                                             46.055     0.334    (1, 12)     5       1
# fused_sigmoid_tanh_multiply_11                                                                            fused_sigmoid_tanh_multiply_1                                                                             44.815     0.325    (1, 12)     5       1
# fused_sigmoid_tanh_multiply_1                                                                             fused_sigmoid_tanh_multiply_1                                                                             43.536     0.315    (1, 12)     5       1
# fused_sigmoid_tanh_multiply3                                                                              fused_sigmoid_tanh_multiply                                                                               38.499     0.279    (1, 10)     5       1
# fused_sigmoid_tanh_multiply2                                                                              fused_sigmoid_tanh_multiply                                                                               38.137     0.276    (1, 10)     5       1
# fused_sigmoid_tanh_multiply4                                                                              fused_sigmoid_tanh_multiply                                                                               38.135     0.276    (1, 10)     5       1
# fused_sigmoid_tanh_multiply6                                                                              fused_sigmoid_tanh_multiply                                                                               38.127     0.276    (1, 10)     5       1
# ...
# fused_split_73                                                                                            fused_split_7                                                                                             3.29       0.024    (1, 8)      1       4
# fused_split_73                                                                                            fused_split_7                                                                                             3.29       0.024    (1, 8)      1       4
# fused_split_73                                                                                            fused_split_7                                                                                             3.29       0.024    (1, 8)      1       4
# fused_split_73                                                                                            fused_split_7                                                                                             3.29       0.024    (1, 8)      1       4
# fused_split_75                                                                                            fused_split_7                                                                                             3.283      0.024    (1, 8)      1       4
# fused_split_75                                                                                            fused_split_7                                                                                             3.283      0.024    (1, 8)      1       4
# fused_split_75                                                                                            fused_split_7                                                                                             3.283      0.024    (1, 8)      1       4
# fused_split_75                                                                                            fused_split_7                                                                                             3.283      0.024    (1, 8)      1       4
# fused_split_74                                                                                            fused_split_7                                                                                             3.258      0.024    (1, 8)      1       4
# fused_split_74                                                                                            fused_split_7                                                                                             3.258      0.024    (1, 8)      1       4
# fused_split_74                                                                                            fused_split_7                                                                                             3.258      0.024    (1, 8)      1       4
# fused_split_74                                                                                            fused_split_7                                                                                             3.258      0.024    (1, 8)      1       4
# fused_split_71                                                                                            fused_split_7                                                                                             3.25       0.024    (1, 8)      1       4
# fused_split_71                                                                                            fused_split_7                                                                                             3.25       0.024    (1, 8)      1       4
# fused_split_71                                                                                            fused_split_7                                                                                             3.25       0.024    (1, 8)      1       4
# fused_split_71                                                                                            fused_split_7                                                                                             3.25       0.024    (1, 8)      1       4
# fused_split_76                                                                                            fused_split_7                                                                                             3.224      0.023    (1, 8)      1       4
# fused_split_76                                                                                            fused_split_7                                                                                             3.224      0.023    (1, 8)      1       4
# fused_split_76                                                                                            fused_split_7                                                                                             3.224      0.023    (1, 8)      1       4
# fused_split_76                                                                                            fused_split_7                                                                                             3.224      0.023    (1, 8)      1       4
# fused_split_72                                                                                            fused_split_7                                                                                             3.217      0.023    (1, 8)      1       4
# fused_split_72                                                                                            fused_split_7                                                                                             3.217      0.023    (1, 8)      1       4
# fused_split_72                                                                                            fused_split_7                                                                                             3.217      0.023    (1, 8)      1       4
# fused_split_72                                                                                            fused_split_7                                                                                             3.217      0.023    (1, 8)      1       4
# fused_squeeze_171                                                                                         fused_squeeze_17                                                                                          2.291      0.017    (1, 16)     8       1
# fused_squeeze_17                                                                                          fused_squeeze_17                                                                                          2.287      0.017    (1, 16)     8       1
# fused_squeeze_211                                                                                         fused_squeeze_21                                                                                          2.267      0.016    (1, 16)     8       1
# fused_squeeze_21                                                                                          fused_squeeze_21                                                                                          2.265      0.016    (1, 16)     8       1
# fused_squeeze_221                                                                                         fused_squeeze_22                                                                                          2.167      0.016    (1, 16)     8       1
# fused_squeeze_22                                                                                          fused_squeeze_22                                                                                          2.166      0.016    (1, 16)     8       1
# fused_squeeze_24                                                                                          fused_squeeze_24                                                                                          2.132      0.015    (1, 16)     8       1
# fused_squeeze_20                                                                                          fused_squeeze_20                                                                                          2.128      0.015    (1, 16)     8       1
# fused_squeeze_241                                                                                         fused_squeeze_24                                                                                          2.124      0.015    (1, 16)     8       1
# fused_squeeze_201                                                                                         fused_squeeze_20                                                                                          2.108      0.015    (1, 16)     8       1
# fused_squeeze_231                                                                                         fused_squeeze_23                                                                                          2.106      0.015    (1, 16)     8       1
# fused_squeeze_23                                                                                          fused_squeeze_23                                                                                          2.105      0.015    (1, 16)     8       1
# fused_squeeze_30                                                                                          fused_squeeze_30                                                                                          2.085      0.015    (1, 12)     8       1
# fused_squeeze_26                                                                                          fused_squeeze_26                                                                                          2.076      0.015    (1, 12)     8       1
# fused_squeeze_18                                                                                          fused_squeeze_18                                                                                          2.067      0.015    (1, 16)     8       1
# fused_squeeze_181                                                                                         fused_squeeze_18                                                                                          2.06       0.015    (1, 16)     8       1
# fused_squeeze_15                                                                                          fused_squeeze_15                                                                                          2.039      0.015    (1, 10)     8       1
# fused_squeeze_33                                                                                          fused_squeeze_33                                                                                          2.024      0.015    (1, 10)     8       1
# fused_squeeze_191                                                                                         fused_squeeze_19                                                                                          2.014      0.015    (1, 16)     8       1
# fused_squeeze_25                                                                                          fused_squeeze_25                                                                                          2.014      0.015    (1, 12)     8       1
# fused_squeeze_16                                                                                          fused_squeeze_16                                                                                          2.013      0.015    (1, 12)     8       1
# fused_squeeze_19                                                                                          fused_squeeze_19                                                                                          2.012      0.015    (1, 16)     8       1
# fused_squeeze_34                                                                                          fused_squeeze_34                                                                                          2.008      0.015    (1, 10)     8       1
# fused_squeeze_28                                                                                          fused_squeeze_28                                                                                          2.001      0.014    (1, 12)     8       1
# fused_squeeze_31                                                                                          fused_squeeze_31                                                                                          1.98       0.014    (1, 12)     8       1
# fused_squeeze_37                                                                                          fused_squeeze_37                                                                                          1.955      0.014    (1, 10)     8       1
# fused_squeeze_29                                                                                          fused_squeeze_29                                                                                          1.944      0.014    (1, 12)     8       1
# fused_squeeze_38                                                                                          fused_squeeze_38                                                                                          1.938      0.014    (1, 10)     8       1
# fused_squeeze_27                                                                                          fused_squeeze_27                                                                                          1.928      0.014    (1, 12)     8       1
# fused_squeeze_36                                                                                          fused_squeeze_36                                                                                          1.927      0.014    (1, 10)     8       1
# fused_nn_batch_flatten_2                                                                                  fused_nn_batch_flatten_2                                                                                  1.856      0.013    (1, 6)      1       1
# fused_squeeze_35                                                                                          fused_squeeze_35                                                                                          1.83       0.013    (1, 10)     8       1
# fused_squeeze_32                                                                                          fused_squeeze_32                                                                                          1.829      0.013    (1, 10)     8       1
# fused_nn_batch_flatten_1                                                                                  fused_nn_batch_flatten_1                                                                                  1.671      0.012    (1, 4)      1       1
# fused_nn_batch_flatten                                                                                    fused_nn_batch_flatten                                                                                    1.572      0.011    (1, 2)      1       1
# Total_time                                                                                                -                                                                                                         13808.543  -        -           -       -
# (1, 1)
# torch.Size([1, 1, 1])

# %%
print(tvm_output)
with open('output.txt', 'w') as f:
    f.write(cap.stdout)
# Out:
# tensor([[[0.6193]]])

# %%
print(cap)

# %%
print(i_ffc)
# Out:
# [8, 6, 4, 2]

# %%
print(o_ffc)
# Out:
# [6, 4, 2, 1]
